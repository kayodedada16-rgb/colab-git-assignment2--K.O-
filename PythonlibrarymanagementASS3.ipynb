# %% [markdown]
# <a href="https://colab.research.google.com/github/kayodedada16-rgb/colab-git-assignment2--K.O-/blob/main/PythonlibrarymanagementASS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup & Section 1:
#
# Data Types and Variables

# %%
# Python Library Management System

# Install required libraries (This should already exist in colab)
# !pip install requests

import pickle
import sqlite3
import requests

# 1. Data Types and Variables
book_title = "Python Programming"
book_quantity = 5
book_price = 29.99
is_available = True

print(f"Book: {book_title}, Quantity: {book_quantity}, Price: ${book_price}, Available: {is_available}")
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests) (2026.7.22)
# Book: Python Programming, Quantity: 5, Price: $29.99, Available: True

# %% [markdown]
# # Section 2: Lists

# %%
# 2. Lists
books = ["Python Basics", "Advanced Python", "Data Science with Python"]

# >>> COMPLETED TODO: Add two more books to the list
books.append("Machine Learning 101")
books.insert(0, "Introduction to Python")

print("Updated book list:", books)
# Out:
# Updated book list: ['Introduction to Python', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning 101']

# %% [markdown]
# # Section 3 Loops and Range

# %%
# 3. Loops and range()
print("\nAvailable books:")
# >>> COMPLETED TODO: Use a for loop and range() to print books with their indices
for i in range(len(books)):
    print(f"{i}: {books[i]}")
# Out:
# Available books:
# 0: Introduction to Python
# 1: Python Basics
# 2: Advanced Python
# 3: Data Science with Python
# 4: Machine Learning 101

# %% [markdown]
# # Section 4: User Input

# %%
# 4. User Input (from notebook)
new_book = input("Introduction to Algorithms: ")
books.append(new_book)
print("Updated book list:", books)
# Out:
# Introduction to Algorithms: Introduction to Algorithms
# Updated book list: ['Introduction to Python', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning 101', 'Introduction to Algorithms']

# %% [markdown]
# # Sectin 5: Function and Conditional Statement

# %%
# 5. Functions and Conditional Statements
def check_availability(book_name):
    # >>> COMPLETED TODO: Check if the book is in the list and return True if available, False otherwise
    if book_name in books:
        return True
    else:
        return False

# Test the function
print(f"Is 'Python Basics' available? {check_availability('Python Basics')}")
# Out:
# Is 'Python Basics' available? True

# %% [markdown]
# # Section 6: File I/O

# %%
# 6. File I/O
def save_books_to_file(filename):
    with open(filename, 'w') as f:
        for book in books:
            f.write(f"{book}\n")

# >>> COMPLETED TODO: Implement a function to read books from a file
def read_books_from_file(filename):
    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]

# Test file I/O
save_books_to_file("books.txt")
# !cat books.txt # Display file contents in Colab

# Test read function
print("Books read from file:", read_books_from_file("books.txt"))
# Out:
# Introduction to Python
# Python Basics
# Advanced Python
# Data Science with Python
# Machine Learning 101
# Introduction to Algorithms
# Books read from file: ['Introduction to Python', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning 101', 'Introduction to Algorithms']

# %% [markdown]
# # Section 7: Pickle for serialization

# %%
# 7. Pickle for serialization
def save_books_pickle(filename):
    with open(filename, 'wb') as f:
        pickle.dump(books, f)

# >>> COMPLETED TODO: Implement a function to load books using pickle
def load_books_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# Test pickle functions
save_books_pickle("books.pkl")
# Uncomment the next line after implementing load_books_pickle
print("Books loaded from pickle:", load_books_pickle("books.pkl"))
# Out:
# Books loaded from pickle: ['Introduction to Python', 'Python Basics', 'Advanced Python', 'Data Science with Python', 'Machine Learning 101', 'Introduction to Algorithms']

# %% [markdown]
# # Section 8: SQlite Database Interaction

# %%
# !rm library.db

# %%
# 8. SQLite Database Interaction
def create_books_table():
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS books
                      (id INTEGER PRIMARY KEY, title TEXT, quantity INTEGER)''')
    conn.commit()
    conn.close()

# >>> COMPLETED TODO: Implement a function to add a book to the SQLite database
def add_book_to_db(title, quantity):
    conn = sqlite3.connect('library.db')
    cursor = conn.cursor()
    cursor.execute("INSERT INTO books (title, quantity) VALUES (?, ?)", (title, quantity))
    conn.commit()
    conn.close()

# Test database functions
create_books_table()
add_book_to_db("Python for Beginners", 10)

# %% [markdown]
# # Section 9: Web API Interaction (GitHub API)

# %%
# 9. Web API Interaction (GitHub API)
def get_python_repos():
    url = "https://api.github.com/search/repositories"
    params = {"q": "language:python", "sort": "stars", "order": "desc"}
    response = requests.get(url, params=params)
    data = response.json()
    return [repo['name'] for repo in data['items'][:5]]

# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
#
# Library Management System operations completed.

# %% [markdown]
# # TEST API FUNCTION

# %%
# Test API function
print("Top 5 Python repositories on GitHub:", get_python_repos())

print("\nLibrary Management System operations completed.")
# Out:
# Top 5 Python repositories on GitHub: ['public-apis', 'free-programming-books', 'system-design-primer', 'awesome-python', 'project-based-learning']
#
# Library Management System operations completed.

# %% [markdown]
# # THE LINK
#
# https://colab.research.google.com/drive/1nJv0xPZroafnJLb7jAv5UhkhfOO6R4ST?usp=sharing
