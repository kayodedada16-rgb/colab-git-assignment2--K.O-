# %% [markdown]
# <a href="https://colab.research.google.com/github/kayodedada16-rgb/colab-git-assignment2--K.O-/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# # Version Control Commands
#
# Add and commit the notebook to your repository

# %%
# 1. Set your Git identity
# !git config --global user.email "kayodedada16@gmail.com"
# !git config --global user.name "kayodedada16"

# 2. Initialize the Git repository in this Colab session
# !git init

# 3. Add your notebook file
# !git add assignment2.ipynb

# 4. Commit the changes
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# Reinitialized existing Git repository in /content/.git/
# fatal: pathspec 'assignment2.ipynb' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.config/
# 	sample_data/
#
# nothing added to commit but untracked files present (use "git add" to track)
